# %% [markdown]
# # 민감 키워드 매칭도 — 평판 위험도 구성 요소
#
# ## 전체 위험도 프레임워크에서의 위치
# ```
# 최종 위험도 (ABCDF)
# ├── 평판 위험도 33%   댓글 감성 지수 + [민감 키워드 매칭도 ← 현재]
# ├── 트래픽 위험도 33% 이탈 확률 + 정체 확률 + 조회수 변동성 + 업로드 주기 불확실성
# └── 팬덤 위험도 33%   활성 시청자 비율 + 시청 유지 안정성
# ```
#
# ## 데이터 기반
# 재생목록 제목 컬럼이 수집되지 않아 **`video_title` 기반**으로 분석합니다.
# 영상 제목은 재생목록 제목과 마찬가지로 채널의 콘텐츠 방향성을 반영합니다.
#
# ## 출력
# 각 채널에 대해 **민감 키워드 점수 0 ~ 1** 을 출력합니다.
# 1에 가까울수록 민감 콘텐츠 비중이 높아 평판 위험이 큽니다.

# %% [markdown]
# ## 0. 라이브러리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import warnings
warnings.filterwarnings("ignore")

print("라이브러리 로드 완료")
# Out:
# 라이브러리 로드 완료

# %%
# 폰트
import matplotlib.pyplot as plt

# macOS에서 가장 많이 사용하는 설정
plt.rcParams["font.family"] = "AppleGothic" # 혹은 "Apple SD Gothic Neo"
plt.rcParams["axes.unicode_minus"] = False

print("macOS 한글 폰트 설정 완료")
# Out:
# macOS 한글 폰트 설정 완료

# %% [markdown]
# ## 1. 데이터 로드

# %%
long = pd.read_csv("../../data/raw/filtered_dataset_long.csv")
long["video_title"] = long["video_title"].fillna("")

print(f"long shape  : {long.shape}")
print(f"채널 수     : {long['channel_id'].nunique()}")
print(f"영상 제목 수 : {long['video_title'].notna().sum()}")
# Out:
# long shape  : (166449, 18)
# 채널 수     : 3336
# 영상 제목 수 : 166449

# %% [markdown]
# ## 2. 민감 키워드 사전 정의
#
# ### 카테고리 구성 (4개 대분류)
# | 대분류 | 설명 |
# |---|---|
# | 정치/사회 갈등 | 탄핵·내란·시위 등 직접 갈등 유발 표현 |
# | 혐오/차별 | 특정 집단을 향한 혐오·차별 표현 |
# | 자극/어그로성 | 폭로·충격·논란 등 자극적 콘텐츠 |
# | 성인/도박/불법 | 19금·도박·마약 등 명백한 규제 대상 |
#
# ### 가중치 설계 (위험도 차등)
# | 가중치 | 의미 | 예시 |
# |---|---|---|
# | 3점 | 고위험 — 직접적 갈등·혐오·불법 표현 | 탄핵, 혐오, 19금, 마약 |
# | 2점 | 중위험 — 정치적 편향·자극성 있음 | 대통령, 충격, 논란 |
# | 1점 | 저위험 — 맥락에 따라 민감할 수 있음 | 갈등, 싸움, 고소 |
# | −1점 | 오탐 감점 — 무관한 정상 맥락 | 성인병, 불법주차 |

# %%
KEYWORD_DICT = {
    # ── 정치/사회 갈등 ──────────────────────────────────────────────────────
    "정치사회_고위험": {
        "keywords": ["탄핵", "내란", "계엄", "시위", "집회", "파업", "폭동", "쿠데타"],
        "weight"  : 3,
        "category": "정치/사회",
    },
    "정치사회_중위험": {
        "keywords": ["정치", "국힘", "민주당", "대통령", "검찰", "여당", "야당",
                     "윤석열", "이재명", "한동훈"],
        "weight"  : 2,
        "category": "정치/사회",
    },

    # ── 혐오/차별 ───────────────────────────────────────────────────────────
    "혐오차별_고위험": {
        "keywords": ["혐오", "차별", "한남", "김치녀", "여혐", "남혐", "인종차별",
                     "틀딱", "노인충", "맘충"],
        "weight"  : 3,
        "category": "혐오/차별",
    },

    # ── 자극/어그로 ─────────────────────────────────────────────────────────
    "자극_고위험": {
        "keywords": ["폭로", "사기", "저격", "고소", "욕설", "쓰레기", "개XX",
                     "협박", "성희롱", "괴롭힘"],
        "weight"  : 3,
        "category": "자극/어그로",
    },
    "자극_중위험": {
        "keywords": ["충격", "논란", "갈등", "싸움", "미친", "어그로", "폭행",
                     "난리", "분노", "激"],
        "weight"  : 2,
        "category": "자극/어그로",
    },
    "자극_저위험": {
        "keywords": ["자극", "강렬", "도발", "파격", "위험"],
        "weight"  : 1,
        "category": "자극/어그로",
    },

    # ── 성인/도박/불법 ──────────────────────────────────────────────────────
    "성인도박불법_고위험": {
        "keywords": ["19금", "도박", "카지노", "마약", "음란", "불법도박",
                     "베팅", "토토", "성인방송"],
        "weight"  : 3,
        "category": "성인/도박/불법",
    },

    # ── 오탐 감점 (정상 맥락) ───────────────────────────────────────────────
    "오탐_감점": {
        "keywords": ["성인병", "성인식", "성인용품샵", "불법주차", "불법건축",
                     "갈등해결", "충격요법", "논란없는"],
        "weight"  : -1,
        "category": "오탐",
    },
}

# 전체 키워드 수 확인
total_kw = sum(len(v["keywords"]) for k, v in KEYWORD_DICT.items() if v["weight"] > 0)
print(f"민감 키워드 총 {total_kw}개 정의 완료")
print()
for name, info in KEYWORD_DICT.items():
    flag = "⚠ 오탐감점" if info["weight"] < 0 else f"가중치 {info['weight']}점"
    print(f"  [{info['category']:10s}] {name:20s} {flag} | {info['keywords']}")
# Out:
# 민감 키워드 총 62개 정의 완료
#
#   [정치/사회     ] 정치사회_고위험             가중치 3점 | ['탄핵', '내란', '계엄', '시위', '집회', '파업', '폭동', '쿠데타']
#   [정치/사회     ] 정치사회_중위험             가중치 2점 | ['정치', '국힘', '민주당', '대통령', '검찰', '여당', '야당', '윤석열', '이재명', '한동훈']
#   [혐오/차별     ] 혐오차별_고위험             가중치 3점 | ['혐오', '차별', '한남', '김치녀', '여혐', '남혐', '인종차별', '틀딱', '노인충', '맘충']
#   [자극/어그로    ] 자극_고위험               가중치 3점 | ['폭로', '사기', '저격', '고소', '욕설', '쓰레기', '개XX', '협박', '성희롱', '괴롭힘']
#   [자극/어그로    ] 자극_중위험               가중치 2점 | ['충격', '논란', '갈등', '싸움', '미친', '어그로', '폭행', '난리', '분노', '激']
#   [자극/어그로    ] 자극_저위험               가중치 1점 | ['자극', '강렬', '도발', '파격', '위험']
#   [성인/도박/불법  ] 성인도박불법_고위험           가중치 3점 | ['19금', '도박', '카지노', '마약', '음란', '불법도박', '베팅', '토토', '성인방송']
#   [오탐        ] 오탐_감점                ⚠ 오탐감점 | ['성인병', '성인식', '성인용품샵', '불법주차', '불법건축', '갈등해결', '충격요법', '논란없는']

# %% [markdown]
# ## 3. 채널별 민감 키워드 점수 계산
#
# ### 점수 계산 로직
#
# ```
# 영상별 raw_score = Σ (매칭된 키워드의 가중치)
# 채널 raw_score   = Σ (모든 영상의 raw_score)
# 정규화           = raw_score / (영상 수 × 최대가중치3) → 0~1 클리핑
# ```
#
# 단순 매칭 수 대신 **영상 수로 나눠 정규화**하는 이유:
# 영상이 많은 채널이 무조건 높은 점수를 받지 않도록 합니다.

# %%
def calc_sensitive_score(group):
    titles      = group["video_title"].tolist()
    n_videos    = len(titles)
    channel_raw = 0
    cat_counts  = {cat: 0 for cat in ["정치/사회","혐오/차별","자극/어그로","성인/도박/불법"]}
    matched_titles = []

    for title in titles:
        video_score = 0
        video_matches = []

        for group_name, info in KEYWORD_DICT.items():
            for kw in info["keywords"]:
                if kw in str(title):
                    video_score += info["weight"]
                    if info["weight"] > 0:
                        video_matches.append((kw, info["category"], info["weight"]))
                        cat_counts[info["category"]] = cat_counts.get(info["category"], 0) + 1

        if video_score > 0:
            matched_titles.append({
                "title"  : title,
                "score"  : video_score,
                "matches": video_matches,
            })
        channel_raw += max(video_score, 0)   # 영상별 음수는 0으로 클램프

    # 정규화: 채널 내 영상당 평균 점수 / 최대 가중치(3)
    normalized = channel_raw / (n_videos * 3 + 1e-9)
    normalized = float(np.clip(normalized, 0, 1))

    return pd.Series({
        "raw_score"             : channel_raw,
        "sensitive_score"       : round(normalized, 4),
        "n_sensitive_videos"    : len(matched_titles),
        "sensitive_video_ratio" : round(len(matched_titles) / (n_videos + 1e-9), 4),
        "cat_politics"          : cat_counts.get("정치/사회", 0),
        "cat_hate"              : cat_counts.get("혐오/차별", 0),
        "cat_aggro"             : cat_counts.get("자극/어그로", 0),
        "cat_adult_illegal"     : cat_counts.get("성인/도박/불법", 0),
        "top_matched_titles"    : str([m["title"][:30] for m in matched_titles[:3]]),
    })

score_df = long.groupby("channel_id").apply(
    calc_sensitive_score, include_groups=False
).reset_index()

# 채널 제목 붙이기
titles_map = long.groupby("channel_id")["channel_title"].first().reset_index()
score_df   = score_df.merge(titles_map, on="channel_id")

print(f"채널 수: {len(score_df)}")
print()
print("=== sensitive_score 분포 ===")
print(score_df["sensitive_score"].describe().round(4))
# Out:
# 채널 수: 3336
#
# === sensitive_score 분포 ===
# count    3336.0000
# mean        0.0251
# std         0.0500
# min         0.0000
# 25%         0.0000
# 50%         0.0133
# 75%         0.0333
# max         0.7733
# Name: sensitive_score, dtype: float64

# %% [markdown]
# ## 4. 결과 확인

# %%
result = score_df[[
    "channel_id","channel_title","sensitive_score",
    "n_sensitive_videos","sensitive_video_ratio",
    "cat_politics","cat_hate","cat_aggro","cat_adult_illegal",
    "top_matched_titles"
]].sort_values("sensitive_score", ascending=False).reset_index(drop=True)

print("=== 민감 키워드 점수 상위 채널 ===")
print(result[["channel_title","sensitive_score","n_sensitive_videos",
              "cat_politics","cat_aggro","top_matched_titles"]].head(10).to_string(index=False))
# Out:
# === 민감 키워드 점수 상위 채널 ===
#              channel_title  sensitive_score  n_sensitive_videos  cat_politics  cat_aggro                                                                                     top_matched_titles
#                       루스명품           0.7733                  37             0          2                          ['아버님 놀라지말고 들어보세요 #카지노', '느그들 구라면 손모가지 다 잘라 삔다 #카지노', '진짜 3천만원에 사시겠다고요 #카지노']
#               미친감성 (감성사운드)           0.7000                  47             1         52 ['BTS 제이홉 프랑스와 한국 MAMA 차이나는 이유 [', 'BTS 제이홉 무대를 보고 해외 유명 프로듀서가 감탄을', '지드래곤 TOO BAD 프로 작곡가들이 서태지를 넘어섰']
#                      강스라이팅           0.6933                  29            43          5 ['[강스라이팅] 밴스 그린란드 방문 / 기밀 유출, 미-', '[강스브리핑] 이재명 운명의 날 탄탄대로냐 가시밭길이냐', "[강스브리핑] 산불 확산 여전한데...비는 '찔끔' /"]
#                       온마이크           0.6733                  32            46          4 ['윤석열-박근혜 50분 회동…"면목 없어, 늘 죄송했다"', '발표 직후 취재진 만난 한동훈 "검찰, 나쁜놈 잘 잡으', '윤석열, 안철수 인선 갈등에 "이해 안 된다... 아무']
#                     더빙신안윤상           0.6267                  32            45          1          ['[수리남 더빙] 마약왕 궁예..너 마구니 들렸어?', '[수리남더빙] 디스 이즈 윤석열 집사님...', '[더빙] 아침마당 BGM 정치인 아카펠라 버전...(f']
# 풋볼 포레스트 - Forrest Football           0.4733                  27             0         33 ['“소니는 사랑할수 밖에 없는 선수야”  오늘 생일인 꼬', '"LA는 챔스 4강, 토트넘은 강등위기" 손흥민 이적후', '"이제는 강등이 거의 확실해졌다.." 토트넘 강등권 탈']
#                    점집 용군TV           0.4467                  22             2         29 ['굿 할 때 사과 값 논란, 그 뒤에 숨은 심리적 진실!', '내 새끼보다 그놈이 좋아! 자식 버리고 도망간 미친 큰', '살목지 영화! 무당이 직접 보고 느낀 충격! 용군TV ']
#                      트래블튜브           0.4467                  32             0         34 ['"한국배 호르무즈 통과가능 하다"이란의 초대형 발언 난', '속보, UAE 원유 2400만 배럴 확보충격보고서 주변', '대만, 한국에 최후통첩 강력경고 이란전이후 황당발언 난']
#                    기묘한 케이지           0.4067                  17             2         22 ['톰 크루즈 vs 브래드 피트!💥 미친 크로스오버각 나온', '"X같은 헐리웃 뜹니다!💥" 안젤리나 졸리, 캄보디아행', '"친목, 정치, 조롱까지..💥" 지상 최대 시상식에서 ']
#                댓글 읽어주는 기자들           0.4000                  22            20          6 ['2023. 7. 5.넉달동안 74억 쓰고 자료없다고? ', '2023. 7. 25.●라이브/시사기획창 같이 보기/공', '2023. 8. 28.●라이브/윤석열 이동관 연설 분석']

# %% [markdown]
# ## 5. 시각화

# %%
# ── 채널별 민감 점수 바차트 ─────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

# 왼쪽: 전체 채널 민감 점수 (내림차순)
colors = ["#D85A30" if v >= 0.1 else "#5DCAA5" if v < 0.03 else "#EF9F27"
          for v in result["sensitive_score"]]
axes[0].barh(result["channel_title"], result["sensitive_score"],
             color=colors, edgecolor="none")
for i, v in enumerate(result["sensitive_score"]):
    if v > 0:
        axes[0].text(v + 0.001, i, f"{v:.3f}", va="center", fontsize=7)
axes[0].axvline(0.1, color="#D85A30", linestyle="--", linewidth=1, alpha=0.6, label="고위험 기준(0.1)")
axes[0].axvline(0.03, color="#EF9F27", linestyle="--", linewidth=1, alpha=0.6, label="중위험 기준(0.03)")
axes[0].set_xlabel("민감 키워드 점수 (0~1)")
axes[0].set_title("채널별 민감 키워드 점수\n빨강≥0.1 고위험  주황≥0.03 중위험  초록 안전")
axes[0].legend(fontsize=8)
axes[0].tick_params(axis="y", labelsize=8)

# 오른쪽: 카테고리별 스택 바차트 (상위 15개)
top15 = result.head(15).sort_values("sensitive_score")
cat_cols = ["cat_politics","cat_hate","cat_aggro","cat_adult_illegal"]
cat_labels = ["정치/사회","혐오/차별","자극/어그로","성인/도박/불법"]
cat_colors = ["#378ADD","#D85A30","#EF9F27","#7F77DD"]

left = np.zeros(len(top15))
for col, label, color in zip(cat_cols, cat_labels, cat_colors):
    vals = top15[col].values
    axes[1].barh(top15["channel_title"], vals, left=left,
                 label=label, color=color, edgecolor="none", alpha=0.85)
    left += vals

axes[1].set_xlabel("민감 키워드 매칭 횟수")
axes[1].set_title("카테고리별 민감 키워드 분포 (상위 15개 채널)")
axes[1].legend(fontsize=8, loc="lower right")
axes[1].tick_params(axis="y", labelsize=8)

plt.tight_layout()
plt.show()

# %%
# 점수 분포 히스토그램 + 위험도 구간
fig, ax = plt.subplots(figsize=(7, 4))
ax.hist(result["sensitive_score"], bins=15,
        color="#378ADD", edgecolor="white", alpha=0.8)
ax.axvline(0.03, color="#EF9F27", linestyle="--", lw=1.5, label="중위험(0.03)")
ax.axvline(0.10, color="#D85A30", linestyle="--", lw=1.5, label="고위험(0.10)")
ax.set_xlabel("민감 키워드 점수 (0~1)")
ax.set_ylabel("채널 수")
ax.set_title("민감 키워드 점수 분포")
ax.legend()
plt.tight_layout()
plt.show()

# 위험 구간별 채널 수
low    = (result["sensitive_score"] <  0.03).sum()
mid    = ((result["sensitive_score"] >= 0.03) & (result["sensitive_score"] < 0.10)).sum()
high   = (result["sensitive_score"] >= 0.10).sum()
print(f"안전  (0.00~0.03): {low}개 채널")
print(f"중위험(0.03~0.10): {mid}개 채널")
print(f"고위험(0.10~1.00): {high}개 채널")
# Out:
# 안전  (0.00~0.03): 2475개 채널
# 중위험(0.03~0.10): 689개 채널
# 고위험(0.10~1.00): 172개 채널

# %% [markdown]
# ## 6. 저장

# %%
output = result[[
    "channel_id","channel_title",
    "sensitive_score","n_sensitive_videos","sensitive_video_ratio",
    "cat_politics","cat_hate","cat_aggro","cat_adult_illegal",
]].copy()

output.to_csv("../../data/raw/sensitive_keyword_score.csv", index=False, encoding="utf-8-sig")
print("저장 완료: sensitive_keyword_score.csv")
print()
print("=== 최종 출력 샘플 ===")
print(output[["channel_title","sensitive_score","n_sensitive_videos"]].to_string(index=False))
#                                    코딩하는거니           0.0867                   5
#                                  로블록스 선생님           0.0867                   6
#                                인도네시아를 그리다           0.0867                   7
#                                 아이템의 인벤토리           0.0867                   6
#                              세탁설 setaksul           0.0867                   5
#                                        혜성           0.0867                   5
#                               일본인스타시오리しおり           0.0867                   6
#                                       이과장           0.0867                   7
#                       제이치핏 Jay itchy feet           0.0867                   6
#                       캠핑제국 Camping Empire           0.0867                   9
#                         감자매 Potato sister           0.0867                   7
#                                 김채호의 필름찢기           0.0867                   5
#                                    주식급등정보           0.0833                   2
#                       123 GO! FOOD Korean           0.0800                   6
#                                        써니           0.0800                   5
#                             김승현 안피디의 스포일러           0.0800                   6
#                                    하수구의제왕           0.0800                   6
#                                       효자손           0.0800                   6
#                          백지영 Baek Z Young           0.0800                   6
#                                       미선짱           0.0800                   5
#                                      Rush           0.0800                   4
#                                     수닝유튜브           0.0800                   6
#                                 라이너의 컬쳐쇼크           0.0800                   6
#                                  현주zutube           0.0800                   5
#                                        수피           0.0800                   5
#                                      스간TV           0.0800                   6
#                        송숲 세계여행 songforest           0.0800                   5
#                                        준등           0.0800                   4
#                                       하얀귤           0.0800                   4
#                              홍고고 HONGGOGO           0.0800                   5
#                                     아구 TV           0.0800                   5
#                               EMK MUSICAL           0.0800                   6
#                    세부필리핀 초이 사장 Owner Choi           0.0800                   5
#                              GuzalTV 구잘TV           0.0800                   6
#                                        튜나           0.0800                   4
#                                       맛삼인           0.0800                   6
#                                        빅윈           0.0800                   4
#                        캡틴라미[captain ramy]           0.0800                   6
#                                     환경스페셜           0.0800                   5
#                                      나라카일           0.0800                   5
#                        고니두욘몬 Goniduyonmon           0.0800                   6
#         Kevin's Military Channel : KKMD !           0.0800                   5
#                                 희재 HEEJAE           0.0800                   5
#                                      근성마톡           0.0800                   4
#                                에드머 Edmmer           0.0800                   6
#                                     Topic           0.0800                   7
#                  놀라운 토요일 Amazing Saturday           0.0800                   5
#                            특종세상 - 그때 그 사람           0.0800                   5
#                                      모르는지           0.0800                   2
#                             DOCLIP :: 두클립           0.0800                   6
#                                  빡다혜dahye           0.0800                   6
#                                  주식랠리정보TV           0.0800                   6
#                                   채널 명예훈장           0.0800                   6
#                                   에이트 ATE           0.0800                   6
#                                       빼밀리           0.0800                   5
#                         스포츠머그 - SPORTSMUG           0.0800                   6
#                             신지우 shinjiwoo           0.0800                   5
#                               휘토피아 htopia           0.0800                   5
#                                     캐인유튜브           0.0800                   7
#                                        유성           0.0800                   5
#                                      앵그리팁           0.0762                   4
#                                       버미쌤           0.0733                   5
#                             Tacosama 타코사마           0.0733                   5
#                            심킹 (ABYSSKIMG)           0.0733                   5
#                      드립팩토리 [Dlib Factory]           0.0733                   4
#                        팔차선 [8LJAYWALKING]           0.0733                   5
#                                     엄태웅TV           0.0733                   4
#                                       드파밍           0.0733                   7
#                          이지무비: Easy Movie           0.0733                   6
#                                     유유타이거           0.0733                   5
#                      스튜디오 훜 : STUDIO HOOK           0.0733                   5
#                                       윤루트           0.0733                   4
#                    가노가노, 간호사 일상 Nursegano           0.0600                   1
#                              이미숙_숙스러운 미숙씨           0.0600                   3
#                                      당황TV           0.0600                   3
#                           필리핀 한량 hanRyang           0.0600                   4
#                                     안전한TV           0.0600                   9
#                                    메도우이헌터           0.0600                   4
#                  기똥찬 똥찬 Amazing ddongchan           0.0600                   4
#                              doomandoo두만두           0.0600                   3
#                                       순위충           0.0600                   4
#                                춘자 YouTube           0.0600                   4
#                                       라디유           0.0600                   4
#               엄마밥상매일Mom's table every day           0.0600                   3
#                                     주키니TV           0.0600                   3
#                                       쉬케치           0.0600                   3
#                                      냥신TV           0.0600                   6
#                                       도그홀           0.0600                   3
#                                 수염 STUDIO           0.0600                   5
#                                       근가놈           0.0600                   3
#                              랩해도돼?RAPTUBE           0.0600                   3
#                                   빅마마 이혜정           0.0600                   3
#                                        카팁           0.0600                   3
#                                       신성조           0.0600                   3
#                      인스펙팅룸 InspectingRoom           0.0600                   5
#                                 스발바르 저장고            0.0600                   5
#                                  deemd 딤디           0.0600                   4
#                                   이시아exia           0.0600                   4
#                                        케이           0.0600                   4
#                                       승상싱           0.0600                   3
#                                      그까이꺼           0.0600                   3
#                                      스낵무비           0.0600                   5
#                                 박상후의 문명개화           0.0600                   4
#                                  간니닌니 패밀리           0.0600                   4
#                                       콕끼리           0.0600                   3
#                                     혀니수혀니           0.0600                   3
#                                      썩쏘TV           0.0600                   4
#                                      발__젭           0.0600                   4
#                                      꺼리튜브           0.0600                   4
#                                  마인의 비하인드           0.0600                   4
#                  Eating what is Given 오스틴           0.0600                   4
#                                  에스오디 SOD           0.0600                   4
#                                 최민준의 아들TV           0.0600                   4
#                                 겜스트GAMEST           0.0600                   3
#                                       윤가놈           0.0600                   4
#                                        피넛           0.0600                   5
#                               조이차니JoyChan           0.0600                   2
#                                       박일만           0.0600                   3
#                                    구미호 요괴           0.0600                   4
#                                       아빠킹           0.0600                   3
#                              송승환의 원더풀 라이프           0.0600                   3
#                                        호왕           0.0600                   3
#                                      올댓스타           0.0600                   4
#                                     369랑께           0.0600                   3
#                                      타임스낵           0.0600                   5
#                                     엔스Ens           0.0600                   3
#                        스튜디오V [ STUDIO V ]           0.0600                   3
#                                       롱수칸           0.0600                   3
#                                    유네린LIN           0.0600                   2
#                                     안녕마이카           0.0600                   4
#                                   Aran TV           0.0600                   3
#                                      산골여행           0.0600                   3
#                                샌드박스 에듀케이션           0.0600                   4
#                                    하다Hada           0.0600                   5
#                                      아우라M           0.0533                   3
#                                       램찌툰           0.0533                   3
#                        랜덤토랑 Randomtaurant           0.0533                   4
#                        명현만 MYUNG HYUN MAN           0.0533                   4
#                                   SUNBA선바           0.0533                   3
#                                프로동네야구 PDB           0.0533                   4
#                                       김쫀떡           0.0533                   4
#                                    김필재 TV           0.0533                   4
#                         캠핑한끼CampingHankki           0.0533                   4
#                                     강은정TV           0.0533                   4
#                        Mani Land * 마니랜드 *           0.0533                   4
#                                     뻘짓연구소           0.0533                   3
#                     베이블레이드X | BEYBLADE X            0.0000                   0
#                                     민또 경또           0.0000                   0
#                                        휴복           0.0000                   0
#                                      땅콩찐콩           0.0000                   0
#                    RE:REVOLUTION [혁명의 심장]           0.0000                   0
#                                      하늘석양           0.0000                   0

# %%
output
# Out:
#                     channel_id           channel_title  sensitive_score  \
# 0     UCdf4di4k4fU5lio8ZXQx6mQ                    루스명품           0.7733
# 1     UC6nxfRgvAEcUPxQxsvF6lzw            미친감성 (감성사운드)           0.7000
# 2     UCWLdJ-g9j-ZUwlnR7fU1yCQ                   강스라이팅           0.6933
# 3     UCzz58-H0wzmGoFi3MO_9ePQ                    온마이크           0.6733
# 4     UCHkaQ4y4j3zrB0FfTU1Lc9w                  더빙신안윤상           0.6267
# ...                        ...                     ...              ...
# 3331  UCCW6uYIUP4YKKe50k-ktVAw                   민또 경또           0.0000
# 3332  UCCXeZkv4-v2TlH_J49I_icw                      휴복           0.0000
# 3333  UCCZ3InIIho_BmoaZIiiwDSg                    땅콩찐콩           0.0000
# 3334  UCb3XMd6KgVhp48VcJAqEeiw  RE:REVOLUTION [혁명의 심장]           0.0000
# 3335  UC--8ua5dEkuY26fgWkpkz3Q                    하늘석양           0.0000
#
#       n_sensitive_videos  sensitive_video_ratio  cat_politics  cat_hate  \
# 0                     37                   0.74             0         0
# 1                     47                   0.94             1         0
# 2                     29                   0.58            43         0
# 3                     32                   0.64            46         0
# 4                     32                   0.64            45         0
# ...                  ...                    ...           ...       ...
# 3331                   0                   0.00             0         0
# 3332                   0                   0.00             0         0
# 3333                   0                   0.00             0         0
# 3334                   0                   0.00             0         0
# 3335                   0                   0.00             0         0
#
#       cat_aggro  cat_adult_illegal
# 0             2                 37
# 1            52                  0
# 2             5                  0
# 3             4                  0
# 4             1                  1
# ...         ...                ...
# 3331          0                  0
# 3332          0                  0
# 3333          0                  0
# 3334          0                  0
# 3335          0                  0
#
# [3336 rows x 9 columns]

# %% [markdown]
# ## 점수 해석 가이드
#
# | 점수 구간 | 위험도 | 의미 |
# |---|---|---|
# | 0.00 ~ 0.03 | 안전 | 민감 콘텐츠 거의 없음 |
# | 0.03 ~ 0.10 | 중위험 | 일부 자극적·정치적 콘텐츠 포함 |
# | 0.10 ~ 1.00 | 고위험 | 민감 콘텐츠 비중 높아 평판 리스크 존재 |
#
# ## 한계 및 개선 방향
#
# | 한계 | 개선 방향 |
# |---|---|
# | 단순 문자열 매칭 → 맥락 무시 (예: "충격적으로 맛있는") | 댓글 감성 분석(KoBERT)과 결합 시 정확도 향상 |
# | 키워드 사전이 고정됨 | 정기적 키워드 업데이트 필요 |
# | 재생목록 제목 미수집 | 팀원이 수집 후 `playlist_title` 컬럼 추가 시 대체 가능 |
#
# ## 다음 통합 단계
# 이 점수(`sensitive_score`)는 **평판 위험도 33%** 중
# 댓글 감성 지수와 함께 가중 평균으로 합산됩니다.
#
# ```python
# 평판_위험도 = (댓글_감성_위험점수 × 0.5) + (sensitive_score × 0.5)
# ```
